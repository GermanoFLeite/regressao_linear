# %% [markdown]
# # Regressão Linear

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


tamanho_casa = np.random.randint(100,300,100)

preco_casa = 500 * tamanho_casa + np.random.randint(10000,30000,100)

plt.scatter(tamanho_casa, preco_casa, label='Dados Reais')

model = LinearRegression()

model.fit(tamanho_casa.reshape(-1, 1), preco_casa)  #vai dar erro kkkkk

preco_pred = model.predict(tamanho_casa.reshape(-1,1))

plt.plot(tamanho_casa, preco_pred, label='Dados do modelo', color = 'r')

plt.title('Regressão Linear')
plt.xlabel('Tamanho da Casa')
plt.ylabel('Preço da Casa')

plt.show()

#Temos de ter o controle da aleatoriedade

# %%
model.predict(np.array([[200]]))
# Out:
# array([119829.97620407])

# %%
test = np.random.randint(100, 300, 10)
test
# Out:
# array([207, 259, 136, 266, 213, 184, 149, 162, 237, 209])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

np.random.seed(0)

tamanho_casa = np.random.randint(100,300,100)

preco_casa = 500 * tamanho_casa + np.random.randint(10000,30000,100)

plt.scatter(tamanho_casa, preco_casa, label='Dados Reais')

model = LinearRegression()

model.fit(tamanho_casa.reshape(-1, 1), preco_casa)  #vai dar erro kkkkk

preco_pred = model.predict(tamanho_casa.reshape(-1,1))

plt.plot(tamanho_casa, preco_pred, label='Dados do modelo', color = 'r')

plt.title('Regressão Linear')
plt.xlabel('Tamanho da Casa')
plt.ylabel('Preço da Casa')

plt.show()

# %% [markdown]
# # Multi Variável

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error


np.random.seed(0)

tamanho = np.random.randint(100,300,100)
quantidade_quartos = np.random.randint(1, 10, 100)
quantidade_andares = np.random.randint(1, 5, 100)
idade_casa = np.random.randint(1, 50, 100)

preco = 500 * tamanho_casa + 10000 * quantidade_quartos + 10000 * quantidade_andares - 1000 * idade_casa + np.random.randint(10000,30000,100)

model = LinearRegression()

#Usando o transposto <T> para agrupar as informações cada posição do Array: [T,QQ,QA,I]
dados_casa = np.array([tamanho_casa, quantidade_quartos, quantidade_andares, idade_casa]).T

model.fit(dados_casa, preco)

preco_pred = model.predict(dados_casa)

mae = mean_absolute_error(preco, preco_pred)
mse = mean_squared_error(preco, prec-o_pred)

print(f'MAE = ${mae:.12f}')
print(f'MSE = ${mse:.12f}')
# Out:
# MAE = $5504.407188694035
# MSE = $38972986.546737603843

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

np.random.seed(0)

tamanho = np.random.randint(100,300,100)
quantidade_quartos = np.random.randint(1, 10, 100)
quantidade_andares = np.random.randint(1, 5, 100)
idade_casa = np.random.randint(1, 50, 100)

preco = 500 * tamanho_casa + 10000 * quantidade_quartos + 10000 * quantidade_andares - 1000 * idade_casa + np.random.randint(10000,30000,100)

model = LinearRegression()

#Usando o transposto <T> para agrupar as informações cada posição do Array: [T,QQ,QA,I]
dados_casa = np.array([tamanho_casa, quantidade_quartos, quantidade_andares, idade_casa]).T

scale = StandardScaler()

dados_casa_norm = scale.fit_transform(dados_casa)

model.fit(dados_casa_norm, preco)

preco_pred = model.predict(dados_casa_norm)

mae = mean_absolute_error(preco, preco_pred) # média absoluta de erro
mse = mean_squared_error(preco, preco_pred)  # média absoluta de erro ao quadrado

######
#MAE ==> Usando para considerar os valores "outlines" da equação
######


print(f'MAE = ${mae:.12f}')
print(f'MSE = ${mse:.12f}')
# Out:
# MAE = $5504.407188694038
# MSE = $38972986.546737626195

# %% [markdown]
# # Regressão Logística

# %% [markdown]
# Para classificação utilizaremos a Regressão logística

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

dataset = load_iris()

X = dataset.data
y = dataset.target

print(f'Quantidade de dados: {np.unique(y, return_counts=True)}')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.4, random_state=0)

model = LogisticRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

acc = accuracy_score(y_test, y_pred)

print(f'Acurácia = {acc*100:.2f}%')

cm = confusion_matrix(y_test, y_pred)
print(cm)


#acessar o kaggle.com
# coursera
# Deep Learning
# Out:
# Quantidade de dados: (array([0, 1, 2]), array([50, 50, 50]))
# Acurácia = 91.67%
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  4 17]]
